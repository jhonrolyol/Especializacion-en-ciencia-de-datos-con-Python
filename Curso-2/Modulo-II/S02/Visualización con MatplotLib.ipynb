# %% [markdown]
# # <u>Visualización con Matplotlib</u>

# %% [markdown]
# Importar las librerías necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Interfaz Pyplot

# %% [markdown]
# * Permite llevar a cabo la función plot: listas, arrays
# * Personalizar las líneas,colores, leyendas, etc.
# * Ofrece un conjunto de tipos de graficas: hist(), scatter(), boxplot(), etc.
# * Identificar los componentes:
#     * Datos: Listas, ndarray, Pandas Series
#     * Elementos: Titulos, nombre de los ejes, etc. Se accede a los elementos básicos con **.plt**
# <br>
# * markers: https://matplotlib.org/api/markers_api.html
# * Leyenda: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.legend.html
# * Colores: https://matplotlib.org/api/colors_api.html
# * Estilos: https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %% [markdown]
# ### 1. Gráfico de línea

# %% [markdown]
# Caso 1:
# * Datos: Listas
# * Representación: Una línea con los puntos de cada lista

# %%
# Definiendo listas
a = [1, 2, 3, 4]
b = [11, 22, 33, 44]

# %% [markdown]
# #### Ejemplo
# Muestre un gráfico de linea teniendo en el eje x a la lista a y en y a la lista b

# %%
plt.plot(a, b)
plt.show()

# %% [markdown]
# #### Ejemplo
# Ahora que el gráfico sea con puntos de color rojo y el marcador sea círculos

# %%
plt.plot(a, b, 'ro')
plt.show()

# %% [markdown]
# #### Ejemplo
# Ahora que el gráfico sea con puntos de color azul y el marcador sea círculos

# %%
plt.plot(a, b, 'bo')
plt.show()

# %% [markdown]
# #### Ejemplo
# Especifíque que el eje x sea de 0 a 6, mientras que el eje y sea de 0 a 60

# %%
plt.plot(a, b, 'ro')
plt.axis([0, 6, 0, 60]) # especifica la ventana gráfica de los ejes.[xmin, xmax, ymin, ymax]
plt.show()

# %%
# Definiendo las listas a y b
a = [1, 2, 3, 4]
b = [11, 22, 33, 44]

# %% [markdown]
# #### Ejemplo
# Muestre un gráfico de linea color rojo teniendo en el eje x a la lista a y en el eje y a la lista b.
# <br>
# Además agrege leyenda 'línea'.

# %%
plt.plot(a, b, color='red', linewidth=2, label='línea')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Ejemplo
# Muestre un gráfico de linea con un marcador circular y un estilo de linea --

# %%
plt.plot([0, 0.1, 0.2, 0.5, 0.6],
         [1,  -1,   0,   3,  -1], 
         marker = 'o',
         linestyle = '--')
plt.show()

# %% [markdown]
# #### Ejemplo
# Muestre un gráfico de linea verde con un marcador de diamante delgado (d) con un estilo de linea dashed line style (--).
# <br>
# Además agrege leyenda 'línea'

# %%
plt.plot(a, b, color='g', marker='d', linestyle='dashed', linewidth=5, label='línea', markersize=12)
plt.legend()
plt.show()

# %% [markdown]
# Caso 2
# * Datos: Array
# * Representación: Una función en un solo sistema de ejes

# %%
x=np.linspace(-1,5,20)

# %%
x
# Out:
# array([-1.        , -0.68421053, -0.36842105, -0.05263158,  0.26315789,
#         0.57894737,  0.89473684,  1.21052632,  1.52631579,  1.84210526,
#         2.15789474,  2.47368421,  2.78947368,  3.10526316,  3.42105263,
#         3.73684211,  4.05263158,  4.36842105,  4.68421053,  5.        ])

# %%
def f(x):
    return np.exp(-x**2)

# %%
# Calculando la función a los valores del objeto x
f(x)
# Out:
# array([3.67879441e-01, 6.26163322e-01, 8.73074777e-01, 9.97233750e-01,
#        9.33091439e-01, 7.15209297e-01, 4.49080097e-01, 2.30991593e-01,
#        9.73307906e-02, 3.35958813e-02, 9.49956097e-03, 2.20040560e-03,
#        4.17526127e-04, 6.49002372e-05, 8.26400593e-06, 8.62018660e-07,
#        7.36587634e-08, 5.15601165e-09, 2.95654890e-10, 1.38879439e-11])

# %% [markdown]
# #### Ejemplo
# Muestre un gráfico para la función f(x).
# <br>
# Título: "Grafica de la función f(x)"
# <br>
# X: "Eje X"
# <br>
# Y: "Eje Y"
# <br>
# Eje X: [-1, 5]
# <br>
# Eje Y: [-0.5, 2]
# <br>
# Leyenda: 'f(x)'

# %%
# Elementos: .plt()
# Representando un solo gráfico

plt.figure(figsize = (10,5)) # Aumentar el tamaño de la ventana (ancho, alto) en pulgadas
plt.title("Grafica de la función f(x)")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.axis((-1,5,-0.5,2))
plt.plot(x,f(x),
         marker = 'o',
         linewidth = 6, #Aumentar el tamaño de la línea
         color = 'r',
         alpha = 0.8, #Tonalidad de la línea
         markersize=15,
         linestyle = '--',
         label = 'f(x)')
plt.legend()
plt.show()

# %%
# Otro ejemplo
npoints = 100

X = np.random.randn(npoints)
Y = -0.4 * X
plt.plot(X,Y, label="otra linea")
plt.grid()   #agrega cuadriculas al gráfico
plt.legend()
plt.show()

# %% [markdown]
# Caso 3
# * Datos: Array
# * Representar: Dos gráficos en un mismo sistema de Ejes

# %%
x=np.linspace(-1,5,20)
x
# Out:
# array([-1.        , -0.68421053, -0.36842105, -0.05263158,  0.26315789,
#         0.57894737,  0.89473684,  1.21052632,  1.52631579,  1.84210526,
#         2.15789474,  2.47368421,  2.78947368,  3.10526316,  3.42105263,
#         3.73684211,  4.05263158,  4.36842105,  4.68421053,  5.        ])

# %%
def fCuadratica(x):
    return x**2

def fCubica(x):
    return x**3

def fQuinta(x):
    return x**5

# %% [markdown]
# #### Ejemplo
# Muestre un gráfico para la función cuadrática y cúbica en mismo sistema de ejes

# %%
plt.figure(figsize=(8,4))
plt.title("Mis gráficos")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.plot(x,fCuadratica(x),
         #marker = '*',
         #color = 'b',
         #linestyle = '-',
         '*b-',
         label ='F(x)**2'
         )

plt.plot(x,fCubica(x),
         #marker = 'o'
         #color = 'k',
         #linestyle = '--',
         'ok--',
         label ='F(x)**3')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# Para otros tipos de estilos: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.figure(figsize=(8,4))
plt.title("Mis gráficos")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.plot(x,fCuadratica(x),
         #marker = '*',
         #color = 'b',
         #linestyle = '-',
         '*b-',
         label ='F(x)**2'
         )

plt.plot(x,fCubica(x),
         #marker = 'o'
         #color = 'k',
         #linestyle = '--',
         'ok--',
         label ='F(x)**3')

plt.plot(x,fQuinta(x),
         #marker = 'o'
         #color = 'g',
         #linestyle = '--',
         'og--',
         label ='F(x)**5')

plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ### 2. Histograma

# %% [markdown]
# Los histogramas representan en altura la acumulación de caso en intervalos de valor. Son apropiados para variables cuantitativas.

# %%
# Definamos la lista values
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]

# %% [markdown]
# ##### Ejemplo
# Genere el histograma de la lista values

# %%
plt.hist(values, bins=3)
plt.show()

# %%
# Generemos datos aleatorios normales
data_normal_1 = np.random.normal(loc = 1.0, scale = 0.5, size = 1000)

# loc: Valor "float", representa el centro de la distribución
# scale: Valor "float", representa la desviación Estandar de la distrib.
# size: un valor "int"
data_normal_1
# Out:
# array([ 0.75734629,  0.93317899,  0.60928284,  0.86536165,  1.46947911,
#         0.88807555,  0.79532797,  0.97912192,  0.44934714,  0.36465146,
#         0.87696561,  0.87764941,  1.30652676,  0.64749282, -0.13935434,
#         0.85086997,  1.04265218,  1.30797462,  1.39857776,  0.49399419,
#         1.2728943 ,  1.37527297,  1.57201122,  1.15724892,  1.93758777,
#         0.98066888,  1.38649614,  0.51936427,  1.20914894,  0.711657  ,
#         0.34650634,  0.35041257,  0.66308507,  1.61827792,  0.70333301,
#         1.30386988,  0.7155036 ,  0.94865822,  1.40811391,  1.36674934,
#         1.00800079,  0.77779479,  1.22835682,  0.64782344,  1.88263069,
#         0.80269446,  0.85244851,  0.74587765,  0.68855171,  0.70017192,
#        -0.0563559 ,  1.59304104,  0.8952188 ,  1.12994609,  1.64620671,
#         1.21044581,  0.9826782 ,  0.88215314,  1.37351328,  2.41349303,
#         1.52037071,  0.71244418,  0.28160209,  1.22423918,  0.96759316,
#         0.6006912 ,  1.27258396,  1.5897113 ,  1.06624863,  1.12971231,
#         0.63101912,  1.13255859,  1.41262097,  0.59790387,  1.97776437,
#         1.51914017,  1.65536298,  0.97404416,  0.98697226,  0.94751142,
#         0.50526788,  1.17240538,  1.48137112,  1.11130611,  1.43783574,
#         0.74653133,  1.09648644,  0.28218404,  0.38822352,  1.19777462,
#         0.58613367,  0.06170409,  0.38812218, -0.3821516 ,  1.04547561,
#         1.25891991,  1.96345415,  1.39766957,  0.81111185,  0.44752155,
#         0.56077448,  1.85045227,  0.4982786 ,  0.34457678,  1.43539574,
#         0.96927243,  1.18916647,  0.68842973,  0.20915124,  1.42078225,
#         1.16131695,  0.95161802,  0.90769069,  0.74954646,  1.92839895,
#         1.26411463,  0.10807295,  0.5990452 ,  0.4484989 ,  1.147286  ,
#         0.92204198,  0.7029415 ,  0.72414192,  1.42604434,  0.58427232,
#         1.40195731,  1.32622437,  1.37920328,  0.52406649,  0.72269458,
#         0.81613761,  1.33673608,  0.34805251,  1.33044354,  1.1613613 ,
#         0.26961607,  0.77809912,  1.48319706,  1.02277649,  0.56735723,
#         1.55630989,  0.28058379,  1.20079063,  1.79561637,  1.27471958,
#         1.80082046,  0.73221841,  0.91412791,  0.23681633,  1.17473222,
#        -0.30089575,  0.04858153,  0.63622321,  0.58961881,  1.21456407,
#         1.06044952,  0.14447483,  1.17050757,  1.70844151,  1.28276133,
#         2.2493222 ,  0.72383128,  0.79558967,  1.35337469,  1.25483344,
#         0.82978837,  0.39882145,  1.22690777,  0.69805321,  1.49860385,
#         0.48427374,  0.7054397 ,  0.67986784,  0.93709185,  0.76487418,
#         0.45072924,  0.3963017 ,  1.5467481 ,  0.85560468,  0.98052702,
#         1.11955685,  1.16138463,  1.13572   ,  0.84800257,  0.36349494,
#         0.60791859,  0.80749993,  1.23086929,  1.03216276,  1.16345694,
#         0.9893416 ,  1.99857712,  0.68889493,  1.37039818,  1.06647135,
#         0.91211733,  0.65955498,  1.09125512,  0.59732116,  1.48064216])

# %%
print(data_normal_1.shape)
print(data_normal_1.dtype)
print(data_normal_1[0:30])
# Out:
# (1000,)
# float64
# [ 0.75734629  0.93317899  0.60928284  0.86536165  1.46947911  0.88807555
#   0.79532797  0.97912192  0.44934714  0.36465146  0.87696561  0.87764941
#   1.30652676  0.64749282 -0.13935434  0.85086997  1.04265218  1.30797462
#   1.39857776  0.49399419  1.2728943   1.37527297  1.57201122  1.15724892
#   1.93758777  0.98066888  1.38649614  0.51936427  1.20914894  0.711657  ]

# %% [markdown]
# #### Ejemplo
# Graficar un histograma para data_normal_1

# %%
plt.title("Histograma")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.hist(data_normal_1,
         bins = 40,
         alpha = 0.6,
         edgecolor ='k',
         label ="Histograma Data 1")
# bins: numero de Intervalos de clase
# alpha: Nitidez -[0-1]
plt.legend()
plt.show()

# %% [markdown]
# #### Ejemplo
# Al histograma anterior agrege que en el eje y solo se muestren las etiquetas 0,20,40,60,80

# %%
plt.title("Histograma")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.hist(data_normal_1,
         bins = 40,
         alpha = 0.6,
         edgecolor ='k',
         label ="Histograma Data 1")
# bins: numero de Intervalos de clase
# alpha: Nitidez -[0-1]

plt.yticks([0,20,40,60,80])

plt.legend()
plt.show()

# %%
data_normal_2 = np.random.normal(loc = 1.5, scale = 0.1, size = 500)
data_normal_3 = np.random.normal(loc = 0.5, scale = 0.6, size = 500)

# %% [markdown]
# #### Ejemplo
# Graficar un histograma para data_normal_2 y data_normal_3 en mismo sistema de ejes

# %%
plt.figure(figsize = (12,8))
plt.title("Histograma")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.hist(data_normal_2,bins = 20,alpha = 0.5, edgecolor = 'k',label ='Hist N2')
plt.hist(data_normal_3,bins = 20,alpha = 0.5,edgecolor = 'k',label = 'Hist N3')
plt.legend()
plt.savefig("Histrograma.png")
plt.show()

# %% [markdown]
# ### 3. Boxplot

# %%
# Cargar un dataset
import pandas as pd
import numpy as np

# %%
#Creación de un objeto
dataset = pd.read_csv('Riesgo_morosidad.csv',sep=',')

# %%
dataset.shape
# Out:
# (8471, 13)

# %%
dataset.head(5)
# Out:
#    edad       sexo  nrodepen fonopart fonolab autovaluo esaval tieneaval  \
# 0    44  Masculino         3       Si      Si        No     No        No
# 1    77  Masculino         4       Si      Si        No     No        Si
# 2    59  Masculino         5       No      No        No     Si        No
# 3    35  Masculino         5       No      Si        No     No        No
# 4    65  Masculino         0       Si      No        No     Si        No
#
#    antiguedad tiporenta  dpto  morosidad nivel_educativo
# 0          63      Fijo  Lima  No Moroso        primaria
# 1          62      Fijo  Lima     Moroso      secundaria
# 2          59      Fijo  Lima     Moroso   universitario
# 3          58      Fijo  Lima     Moroso       bachiller
# 4          56      Fijo  Lima  No Moroso       postgrado

# %% [markdown]
# #### Ejemplo
# Graficar un diagrama de cajas para la variable edad

# %%
plt.figure(figsize = (12,8))
plt.title("edad")
plt.boxplot(dataset['edad'], patch_artist=True)
plt.show()

# %%
dataset['edad'].describe()
# Out:
# count    8471.000000
# mean       45.270098
# std        11.295662
# min        21.000000
# 25%        38.000000
# 50%        43.000000
# 75%        52.000000
# max        77.000000
# Name: edad, dtype: float64

# %% [markdown]
# #### Ejemplo
# Graficar un diagrama de cajas para la variable edad para las categorias de nivel educativo

# %%
import seaborn as sns

# %%
sns.boxplot(x='nivel_educativo', y='edad', data=dataset)
# Out:
# <AxesSubplot: xlabel='nivel_educativo', ylabel='edad'>

# %% [markdown]
# #### Ejemplo
# Graficar un diagrama de cajas para la variable antiguedad

# %%
dataset['antiguedad']
# Out:
# 0       63
# 1       62
# 2       59
# 3       58
# 4       56
#         ..
# 8466     0
# 8467     0
# 8468     0
# 8469     0
# 8470     0
# Name: antiguedad, Length: 8471, dtype: int64

# %%
plt.figure(figsize = (15,8))
plt.title("antiguedad")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.boxplot(dataset['antiguedad'], patch_artist=True,showfliers=False,vert=False) # showfliers=False no muestra los atipicos 
plt.show()

# %% [markdown]
# #### Ejemplo
# Crear un diagrama de cajas para las variables edad, nrodepen y antiguedad

# %%
var_plot =[dataset['edad'],dataset['nrodepen'],dataset['antiguedad']]
var_plot
# Out:
# [0       44
#  1       77
#  2       59
#  3       35
#  4       65
#          ..
#  8466    57
#  8467    57
#  8468    64
#  8469    67
#  8470    69
#  Name: edad, Length: 8471, dtype: int64,
#  0       3
#  1       4
#  2       5
#  3       5
#  4       0
#         ..
#  8466    5
#  8467    3
#  8468    1
#  8469    0
#  8470    1
#  Name: nrodepen, Length: 8471, dtype: int64,
#  0       63
#  1       62
#  2       59
#  3       58
#  4       56
#          ..
#  8466     0
#  8467     0
#  8468     0
#  8469     0
#  8470     0
#  Name: antiguedad, Length: 8471, dtype: int64]

# %%
plt.figure(figsize = (15,8))
plt.boxplot(var_plot, patch_artist=True,labels=['edad','nrodepen','antiguedad'])
plt.show()

# %%
dataset[['nrodepen','edad','antiguedad']].describe()
# Out:
#           nrodepen         edad   antiguedad
# count  8471.000000  8471.000000  8471.000000
# mean      2.488490    45.270098    11.798607
# std       1.785374    11.295662     9.009207
# min       0.000000    21.000000     0.000000
# 25%       1.000000    38.000000     5.000000
# 50%       2.000000    43.000000    10.000000
# 75%       4.000000    52.000000    14.000000
# max       5.000000    77.000000    63.000000

# %% [markdown]
# ### 4. Diagrama de barras

# %%
# Definiendo listas 
x,y=[1, 2, 3], [3, 2, 1]

# %% [markdown]
# #### Ejemplo
# Crear un diagrama de barras para considerando las listas definidas previamente x e y

# %%
plt.figure(figsize=(12,8))
plt.bar(x,y,edgecolor='k', color = ['b','r','g'])
plt.xticks([1,2,3])
plt.show()

# %%
# Definiendo los arrays
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

# %% [markdown]
# #### Ejemplo
# Crear un diagrama de barras para considerando las arrays definidos previamente x e y

# %%
plt.figure(figsize=(12,8))
plt.barh(x, y,edgecolor='k', color = ['k','r','g','skyblue'],alpha=0.5)
plt.show()

# %%
# Definiendo lista de periodo y % de impuesto
x,y = ["Diciembre 2022", "Enero 2023"], [35, 39.6]

# %% [markdown]
# #### Ejemplo
# Error de interpretación de gráfico de barras

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]+0.1,str(y[i])+'%', ha = 'center')
        # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html

plt.figure(figsize=(12,8))
plt.bar(x,y,edgecolor='k', color = 'orange')
plt.axis((-0.5,1.5,34,40))
addlabels(x, y)
plt.xlabel('Periodo')
plt.ylabel('% de impuestos')
plt.show()

# %% [markdown]
# Como debería visualizarse correctamente (Teniendo un valor base de 0 )

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]+0.15,str(y[i])+'%', ha = 'center')

plt.figure(figsize=(12,8))
plt.bar(x,y,edgecolor='k', color = 'orange')
addlabels(x, y)
plt.xlabel('Periodo')
plt.ylabel('% de impuestos')
plt.show()

# %% [markdown]
# #### Ejemplo
# Al gráfico de barras anterior agregar que solo se muestren en el eje y los valores de 0, 10, 20, 30, 40 como '0%', '10%', '20%', '30%', '40%'.
# Además que la intensidad del color de las barras sea menor (alpha=0.5)

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]+0.15,str(y[i])+'%', ha = 'center')

plt.figure(figsize=(12,8))
plt.bar(x,y,edgecolor='k', alpha=0.5 , color = 'orange')
addlabels(x, y)
plt.xlabel('Periodo')
plt.ylabel('% de impuestos')

plt.yticks([0, 10, 20, 30, 40],['0%', '10%', '20%', '30%', '40%']) # Modificando los valores que se muestran en el eje y

plt.show()

# %% [markdown]
# #### Ejemplo
# Al gráfico de barras anterior agregarle su título correspondiente

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]+0.15,str(y[i])+'%', ha = 'center')

plt.figure(figsize=(12,8))
plt.bar(x,y,edgecolor='k', alpha=0.5 , color = 'orange')
addlabels(x, y)
plt.xlabel('Periodo')
plt.ylabel('% de impuestos')
plt.title("Porcentaje de Impuesto a la Renta en 'NOMBRE DEL PAIS'")

plt.yticks([0, 10, 20, 30, 40],['0%', '10%', '20%', '30%', '40%']) # Modificando los valores que se muestran en el eje y

plt.show()

# %% [markdown]
# ### 5. Gráfico de Dispersión

# %% [markdown]
# El grado de asociación lineal que pueden tener dos variables cuantitativas

# %% [markdown]
# #### Ejemplo
# Cree el Diagrama de Dispersión entre la variable edad y antiguedad

# %%
plt.figure(figsize=(12,8))
plt.title("Diagrama de dispersión",fontsize=20)
plt.scatter(dataset['edad'],dataset['antiguedad'],alpha =0.6,color = 'g')
plt.xlabel("edad",fontsize=20)
plt.ylabel("antiguedad",fontsize=20)
plt.show()

# %%
np.corrcoef(dataset['edad'],dataset['antiguedad'])
# Out:
# array([[1.        , 0.56127531],
#        [0.56127531, 1.        ]])

# %% [markdown]
# ##### Ejemplo
# Gráfico de Burbujas

# %%
ingreso_x_p = np.array([1000, 2000 , 50000 , 100000,1400, 1600, 60000, 62000, 80000])
esperanza_vida = np.array([45, 52 , 70 , 72, 70 , 65, 55, 67, 80])
poblacion = np.array([0.1, 0.4 , 1 , 0.9, 0.5, 0.7,0.8,0.4,0.6])

# %%
colors = np.random.rand(len(poblacion))
area = np.pi * (15 * poblacion)**2
plt.scatter(ingreso_x_p, esperanza_vida, s=area, c=colors, alpha=1)
plt.show()

# %%
# Otro Ejemplo 
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 a 15 puntos de radio

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
area
# Out:
# array([1.65998678e+02, 4.19909841e+02, 1.12970688e+02, 2.13328447e+02,
#        2.84093041e+02, 2.02694855e+02, 2.26137395e+01, 1.36037977e-02,
#        5.32088035e+01, 4.50833924e+02, 1.68386142e+02, 1.46303070e+01,
#        4.06507209e+01, 3.70841406e+01, 1.22819408e+02, 1.18243232e+01,
#        3.20923231e+02, 1.72663284e+02, 3.82295680e+01, 1.09556094e+02,
#        3.99152827e+02, 4.03894491e+02, 1.84055355e+01, 2.08180814e+02,
#        3.69931147e+02, 2.06139593e+01, 9.30935865e+01, 2.17545777e+02,
#        6.55659295e-04, 1.30174721e+00, 2.48474159e+01, 2.03692436e+01,
#        1.97750448e+02, 2.19425289e+02, 3.96535430e+02, 8.64921223e-02,
#        3.48588585e+02, 2.13220105e+01, 1.39458332e+02, 1.97362640e+02,
#        6.98914716e+02, 7.09076959e+01, 1.87186907e-03, 3.06161743e+02,
#        3.40452045e+02, 7.39082972e+00, 5.20824922e+02, 4.03868679e+02,
#        2.73131925e+02, 2.93906369e+02])

# %% [markdown]
# ### 6. Subgráficos en varias secciones

# %%
dataset
# Out:
#       edad       sexo  nrodepen fonopart fonolab autovaluo esaval tieneaval  \
# 0       44  Masculino         3       Si      Si        No     No        No
# 1       77  Masculino         4       Si      Si        No     No        Si
# 2       59  Masculino         5       No      No        No     Si        No
# 3       35  Masculino         5       No      Si        No     No        No
# 4       65  Masculino         0       Si      No        No     Si        No
# ...    ...        ...       ...      ...     ...       ...    ...       ...
# 8466    57  Masculino         5       No      No        No     Si        Si
# 8467    57  Masculino         3       Si      No        No     No        Si
# 8468    64  Masculino         1       Si      No        Si     No        No
# 8469    67   Femenino         0       Si      No        Si     No        Si
# 8470    69  Masculino         1       No      No        No     Si        No
#
#       antiguedad tiporenta   dpto  morosidad nivel_educativo
# 0             63      Fijo   Lima  No Moroso        primaria
# 1             62      Fijo   Lima     Moroso      secundaria
# 2             59      Fijo   Lima     Moroso   universitario
# 3             58      Fijo   Lima     Moroso       bachiller
# 4             56      Fijo   Lima  No Moroso       postgrado
# ...          ...       ...    ...        ...             ...
# 8466           0      Fijo  Piura     Moroso       postgrado
# 8467           0      Fijo  Piura  No Moroso        primaria
# 8468           0      Fijo  Piura  No Moroso      secundaria
# 8469           0      Fijo  Piura  No Moroso   universitario
# 8470           0      Fijo  Piura  No Moroso       bachiller
#
# [8471 rows x 13 columns]

# %% [markdown]
# ### Gráfico de 2 figuras

# %%
plt.figure(figsize=(12,8)) ## inician con el tamaño 

plt.subplot(2,1,1) ## la primera poscion de subplot
plt.hist(dataset['edad'])

plt.subplot(2,1,2) ## la segunda poscion de subplot
plt.scatter(dataset['edad'],dataset['antiguedad'],alpha =0.6,color = 'g')
plt.title("Diagrama de dispersión",fontsize=20)
plt.xlabel("edad",fontsize=20)
plt.ylabel("antiguedad",fontsize=20)


plt.show()

# %% [markdown]
# ### Alternativa 2

# %%
# Estructura de generación de una imagen (otra forma de entenderlo)

# Importe el submódulo matplotlib.pyplot y asígnele el nombre plt
import matplotlib.pyplot as plt

# Crea una Figure y Axes con plt.subplots
fig, ax = plt.subplots() 
# Figure object: Es un contenedor que incluye todo lo qu ves en pantalla 
# Axes object: Es la parte de la gráfica que contiene los datos, es donde dibujaremos nuestros datos para visualizarlos

# Llame a la función show para mostrar el resultado
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16, 8))   # divide el espacio gráfico en 2 filas y una columna

## Se agrega la figura 1
ax1.hist(dataset['edad'])

## Se agrega la figura 2
ax2.scatter(dataset['edad'],dataset['antiguedad'],alpha =0.6,color = 'g')
ax2.set_xlabel('edad',fontsize=10) #configura la leyenda de la grafica
ax2.set_ylabel('antiguedad',fontsize=10)
ax2.set_title('Dispersión',fontsize=20)


fig.tight_layout()
plt.show()

# %% [markdown]
# ### Gráfico de 4 figuras

# %%
plt.figure(figsize=(12,8)) ## inician con el tramaño 

plt.subplot(2,2,1) ## la primera posición de subplot
plt.hist(dataset['edad'])

plt.subplot(2,2,2) ## la segunda posición de subplot
plt.scatter(dataset['edad'],dataset['antiguedad'],alpha =0.6,color = 'g')
plt.title("Diagrama de dispersión",fontsize=20)
plt.xlabel("edad",fontsize=20)
plt.ylabel("antiguedad",fontsize=20)

## Se agrega la figura 3
plt.subplot(2,2,3) ## la tercera posición de subplot
plt.boxplot(dataset['edad'], patch_artist=True)

## Se agrega la figura 4
plt.subplot(2,2,4) ## la cuarta posición de subplot
plt.bar(dataset['dpto'], dataset['edad'])


plt.show()

# %% [markdown]
# Más tipos de visualizaciones: https://www.data-to-viz.com/
#
# Más información: https://matplotlib.org/3.2.1/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py

# %% [markdown]
# ### 7. Gráfico Circular

# %%
data=[30,20,15,55]
equipo=["Tecnología","Administración","Ventas","Operaciones"]

# %% [markdown]
# #### Ejemplo
# Cree un gráfico circular para la lista data

# %%
fig, ax = plt.subplots()

ax.pie(data)
plt.show()

# %% [markdown]
# #### Ejemplo
# Agregar las etiquetas que se encuentran en la lista equipo.
# <br>
# Además cambiar a colores pasteles que se definan explicitamente.
# <br>
# Colocarle sombra al gráfico.

# %%
fig, ax = plt.subplots()

ax.pie(data, 
       labels = equipo,
       colors=["SteelBlue","Gold","LightCoral","LimeGreen"],
       shadow=True)
plt.show()

# %%
fig, ax = plt.subplots()

ax.pie(data, 
       labels = equipo,
       colors=["SteelBlue","Gold","LightCoral","LimeGreen"],
       shadow=True,
       autopct='%1.1f%%')
plt.show()

# %%
fig, ax = plt.subplots()

ax.pie(data, 
       labels = equipo,
       colors=["SteelBlue","Gold","LightCoral","LimeGreen"],
       shadow=True,
       autopct='%1.1f%%',
       explode = (0.1,0,0,0))
plt.show()

# %%
fig, ax = plt.subplots()

ax.pie(data, 
       labels = equipo,
       colors=["SteelBlue","Gold","LightCoral","LimeGreen"],
       shadow=True,
       autopct='%1.1f%%',
       explode = (0.1,0,0,0),
       pctdistance=0.7)
plt.show()
